# %%
import pickle

# %%
DATAFILE = "dataset_GOM_1_A_A.pickle"

# %%
with open(f'../data/datasets/type_A/{DATAFILE}', 'rb') as f:
    # load the object from the file using pickle.load()
    dataset = pickle.load(f)

# %%
data_raw = dataset["data"]

# %%
print("Stations: ", dataset["stations"])
print("Years: ", dataset["years"])
print("features: ", dataset["features"])
# Out:
# Stations:  ['42001', '42002', '42003', '42007', '42012', '42019', '42020', '42035', '42036', '42038', '42039', '42040', '42041', '42055']
# Years:  ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
# features:  ['WDIR', 'WSPD', 'WVHT', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP']

# %%
data_raw
# Out:
#                      WDIR_42001  WSPD_42001  PRES_42001  ATMP_42001  \
# 2002-01-01 00:00:00        66.0         9.3      1017.1        22.3
# 2002-01-01 01:00:00        66.0         9.3      1017.1        22.3
# 2002-01-01 02:00:00        67.0         9.4      1017.2        21.9
# 2002-01-01 03:00:00        69.0         9.1      1017.2        22.4
# 2002-01-01 04:00:00        70.0         9.0      1017.1        22.5
# ...                         ...         ...         ...         ...
# 2022-12-31 19:00:00       195.0         0.5      1015.0        25.6
# 2022-12-31 20:00:00       210.0         1.0      1015.0        25.3
# 2022-12-31 21:00:00       231.0         0.6      1014.7        26.4
# 2022-12-31 22:00:00        18.0         0.7      1014.9        25.4
# 2022-12-31 23:00:00        68.0         1.6      1015.0        25.0
#
#                      WTMP_42001  DEWP_42001  WDIR_42002  WSPD_42002  \
# 2002-01-01 00:00:00        25.5        16.8        39.0        10.5
# ...

# %% [markdown]
# # Filter Time

# %%
year = 2020
years_new =['2020', '2021', '2022']
data = data_raw[data_raw.index.year >= year]
data
# Out:
#                      WDIR_42001  WSPD_42001  PRES_42001  ATMP_42001  \
# 2020-01-01 00:00:00        75.0         5.7      1019.0        20.9
# 2020-01-01 01:00:00        70.0         5.4      1019.5        21.2
# 2020-01-01 02:00:00        61.0         4.1      1020.1        21.4
# 2020-01-01 03:00:00        55.0         4.1      1020.2        21.6
# 2020-01-01 04:00:00        37.0         4.1      1020.0        21.6
# ...                         ...         ...         ...         ...
# 2022-12-31 19:00:00       195.0         0.5      1015.0        25.6
# 2022-12-31 20:00:00       210.0         1.0      1015.0        25.3
# 2022-12-31 21:00:00       231.0         0.6      1014.7        26.4
# 2022-12-31 22:00:00        18.0         0.7      1014.9        25.4
# 2022-12-31 23:00:00        68.0         1.6      1015.0        25.0
#
#                      WTMP_42001  DEWP_42001  WDIR_42002  WSPD_42002  \
# 2020-01-01 00:00:00        22.3        15.8        51.0         5.9
# ...

# %%
def filter_data(df, stations):
    filtered_columns = [col for col in df.columns if any(s in col for s in stations)]
    return df[filtered_columns]

# %%
def save_shrinked_dataset(dataset_old, data_new, stations_new, years_new, filename):
    dataset_new = dataset_old
    dataset_new["data"] = data_new
    dataset_new["stations"]= stations_new
    dataset["years"] = years_new


    filepath = f'../data/datasets/publication/center_42002/{filename}.pickle'
    with open(filepath, 'wb') as f:
        pickle.dump(dataset, f)

    print("File successfully saved:")
    print(filepath)

# %%
stations_stage_0 = ["42002"]
data_stage_0 = filter_data(data, stations_stage_0)
save_shrinked_dataset(dataset, data_stage_0, stations_stage_0, years_new, "42002_stage_0")
data_stage_0
# Out:
# File successfully saved:
# ../data/datasets/publication/center_42002/42002_stage_0.pickle
#                      WDIR_42002  WSPD_42002  PRES_42002  ATMP_42002  \
# 2020-01-01 00:00:00        51.0         5.9      1020.3        19.5
# 2020-01-01 01:00:00        48.0         5.9      1020.4        19.4
# 2020-01-01 02:00:00        81.0         6.2      1020.5        19.6
# 2020-01-01 03:00:00        64.0         6.0      1020.4        19.7
# 2020-01-01 04:00:00        72.0         5.7      1020.4        20.0
# ...                         ...         ...         ...         ...
# 2022-12-31 19:00:00        22.0         0.6      1015.9        25.1
# 2022-12-31 20:00:00        88.0         1.2      1015.4        24.7
# 2022-12-31 21:00:00        87.0         1.7      1014.9        24.6
# 2022-12-31 22:00:00        90.0         2.5      1014.9        24.5
# 2022-12-31 23:00:00       116.0         3.7      1015.0        24.5
#
# ...

# %%
stations_stage_1 = ["42002", "42038", "42019"]
data_stage_1 = filter_data(data, stations_stage_1)
save_shrinked_dataset(dataset, data_stage_1, stations_stage_1, years_new, "42002_stage_1")
data_stage_1
# Out:
# File successfully saved:
# ../data/datasets/publication/center_42002/42002_stage_1.pickle
#                      WDIR_42002  WSPD_42002  PRES_42002  ATMP_42002  \
# 2020-01-01 00:00:00        51.0         5.9      1020.3        19.5
# 2020-01-01 01:00:00        48.0         5.9      1020.4        19.4
# 2020-01-01 02:00:00        81.0         6.2      1020.5        19.6
# 2020-01-01 03:00:00        64.0         6.0      1020.4        19.7
# 2020-01-01 04:00:00        72.0         5.7      1020.4        20.0
# ...                         ...         ...         ...         ...
# 2022-12-31 19:00:00        22.0         0.6      1015.9        25.1
# 2022-12-31 20:00:00        88.0         1.2      1015.4        24.7
# 2022-12-31 21:00:00        87.0         1.7      1014.9        24.6
# 2022-12-31 22:00:00        90.0         2.5      1014.9        24.5
# 2022-12-31 23:00:00       116.0         3.7      1015.0        24.5
#
# ...

# %%
stations_stage_2 = ["42002", "42038", "42019", "42020", "42035", "42041"]
data_stage_2 = filter_data(data, stations_stage_2)
save_shrinked_dataset(dataset, data_stage_2, stations_stage_2, years_new, "42002_stage_2")
data_stage_2
# Out:
# File successfully saved:
# ../data/datasets/publication/center_42002/42002_stage_2.pickle
#                      WDIR_42002  WSPD_42002  PRES_42002  ATMP_42002  \
# 2020-01-01 00:00:00        51.0         5.9      1020.3        19.5
# 2020-01-01 01:00:00        48.0         5.9      1020.4        19.4
# 2020-01-01 02:00:00        81.0         6.2      1020.5        19.6
# 2020-01-01 03:00:00        64.0         6.0      1020.4        19.7
# 2020-01-01 04:00:00        72.0         5.7      1020.4        20.0
# ...                         ...         ...         ...         ...
# 2022-12-31 19:00:00        22.0         0.6      1015.9        25.1
# 2022-12-31 20:00:00        88.0         1.2      1015.4        24.7
# 2022-12-31 21:00:00        87.0         1.7      1014.9        24.6
# 2022-12-31 22:00:00        90.0         2.5      1014.9        24.5
# 2022-12-31 23:00:00       116.0         3.7      1015.0        24.5
#
# ...

# %%
stations_stage_3 = ["42002", "42038", "42019", "42020", "42035", "42041", "42040", "42007", "42003"]
data_stage_3 = filter_data(data, stations_stage_3)
save_shrinked_dataset(dataset, data_stage_3, stations_stage_3, years_new, "42002_stage_3")
data_stage_3
# Out:
# File successfully saved:
# ../data/datasets/publication/center_42002/42002_stage_3.pickle
#                      WDIR_42002  WSPD_42002  PRES_42002  ATMP_42002  \
# 2020-01-01 00:00:00        51.0         5.9      1020.3        19.5
# 2020-01-01 01:00:00        48.0         5.9      1020.4        19.4
# 2020-01-01 02:00:00        81.0         6.2      1020.5        19.6
# 2020-01-01 03:00:00        64.0         6.0      1020.4        19.7
# 2020-01-01 04:00:00        72.0         5.7      1020.4        20.0
# ...                         ...         ...         ...         ...
# 2022-12-31 19:00:00        22.0         0.6      1015.9        25.1
# 2022-12-31 20:00:00        88.0         1.2      1015.4        24.7
# 2022-12-31 21:00:00        87.0         1.7      1014.9        24.6
# 2022-12-31 22:00:00        90.0         2.5      1014.9        24.5
# 2022-12-31 23:00:00       116.0         3.7      1015.0        24.5
#
# ...
