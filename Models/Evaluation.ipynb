# %% [markdown]
# # Evaluate the result of Experiments
#
# The aim of this script is to standardize the evaluation of several experiments.

# %%
import pickle
from Experiment_Class import Experiment

# %%
filename = "Dataset_Testing"
#filename = "Most_basic_LSTM"

# open the file for reading in binary mode
report: Experiment
with open(f'../data/reports/{filename}.pickle', 'rb') as f:
    # load the object from the file using pickle.load()
    report = pickle.load(f)

# %%
report.print_settings()
# Out:
# Experiment: Dataset_Testing
# Stations that provide all files from 2013-2022 in GOM
# ---------------------------------------
# Stations: ['41008', '41009', '41112', '41113', '41114', '42001', '42002', '42003', '42012', '42019', '42020', '42022', '42035', '42039', '42040', '42055', '42056', '42099', 'AMRL1', 'APCF1', 'ARPF1', 'BABT2', 'BKTL1', 'BSCA1', 'BURL1', 'BYGL1', 'CAPL1', 'CARL1', 'CDRF1', 'CRTA1', 'CWBF1', 'EPTT2', 'FHPF1', 'FMOA1', 'FMRF1', 'FRDF1', 'FRWL1', 'FWYF1', 'GISL1', 'GNJT2', 'GTOT2', 'KTNF1', 'KYWF1', 'LCLL1', 'LKWF1', 'LONF1', 'LOPL1', 'MBLA1', 'MCGA1', 'MGPT2', 'MTBF1', 'MYPF1', 'NCHT2', 'NPSF1', 'NWCL1', 'OBLA1', 'OPTF1', 'PACF1', 'PACT2', 'PCBF1', 'PCGT2', 'PCLF1', 'PCNT2', 'PILL1', 'PMAF1', 'PNLM6', 'PORT2', 'PSTL1', 'PTAT2', 'PTBM6', 'PTIT2', 'RCPT2', 'RLOT2', 'RSJT2', 'RTAT2', 'SANF1', 'SAPF1', 'SAUF1', 'SDRT2', 'SGOF1', 'SHBL1', 'SHPF1', 'SIPF1', 'SRST2', 'TAQT2', 'TESL1', 'TPAF1', 'TRDF1', 'TSHF1', 'TXPT2', 'VAKF1', 'VCAF1', 'VCAT2', 'VENF1', 'WYCM6']
# Years: ['2021', '2022']
# NaN_Threshold: 0.5
# Features: ['WDIR', 'WSPD', 'WVHT', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP']
# ERA5: False, Stationary Shift: 1, lag: 1, Test-Hours:24
#
# ---------------------------------------
# Preprocessing: Stationary: True, Normalized: True
#
# ---------------------------------------
# Internal Model name: lstm_0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                22800
#
#  dense (Dense)               (None, 63)                3213
#
# =================================================================
# Total params: 26,013
# Trainable params: 26,013
# Non-trainable params: 0
# _________________________________________________________________

# %%
report.print_metrics()
# Out:
# One-Shot-Forecasting:
# MAE: 0.9258647338975046 	MSE: 0.8751076094018476
#
# Recurrent-Forecasting:
# MAE: 78.04265531362896 	MSE: 8040.656489901618

# %%
report.print_one_shot_WTMP()

# %%
report.print_recursive_WTMP()

# %%
report.print_one_shot_forecast()

# %%
report.print_recursive_forecast()
